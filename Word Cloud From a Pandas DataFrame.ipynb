# %% [markdown]
# # Word Cloud From a Pandas DataFrame

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/amankharwal/Website-data/master/spam.csv")
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from wordcloud import WordCloud
#       2 from wordcloud import ImageColorGenerator
#       3 from wordcloud import STOPWORDS
#
# File ~\AppData\Roaming\Python\Python39\site-packages\wordcloud\__init__.py:1
# ----> 1 from .wordcloud import (WordCloud, STOPWORDS, random_color_func,
#       2                         get_single_color_func)
#       3 from .color_from_image import ImageColorGenerator
#       5 __all__ = ['WordCloud', 'STOPWORDS', 'random_color_func',
#       6            'get_single_color_func', 'ImageColorGenerator',
#       7            '__version__']
#
# File ~\AppData\Roaming\Python\Python39\site-packages\wordcloud\wordcloud.py:19
#      17 import sys
#      18 import colorsys
# ---> 19 import matplotlib
#      20 import numpy as np
#      21 from operator import itemgetter
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
text = " ".join(i for i in data.text)
stopwords = set(STOPWORDS)
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)
plt.figure( figsize=(15,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
